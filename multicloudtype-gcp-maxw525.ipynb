# %% [markdown]
# # Multi-cloudtype
# In this notebook, a model that will predict the mask for all four cloud types is looked at.

# %%
import sys
sys.path.append('/home/jupyter/fastai_dev/dev')
from local.data.all import *
from local.vision.all import *
from local.vision.core import *
from local.vision.augment import *
from local.vision import models
from local.basics import *
from local.callback.all import *

# %% [markdown]
# ## Data

# %%
CATS = ['fish', 'flower', 'gravel', 'sugar']

# %% [markdown]
# ### Load the images' file paths and the annotations

# %%
SOURCE = Path('data')

# %%
items = get_image_files(SOURCE/'train_images')

# %%
items[11]
# Out:
# PosixPath('data/train_images/eba901f.jpg')

# %%
PILImage.create(items[11]).show();

# %%
IMG_SHAPE = PILImage.create(items[12]).shape
IMG_SHAPE
# Out:
# (1400, 2100)

# %%
def load_train_annotation(fpath):
    df = pd.read_csv(fpath)
    df['Image'] = df.Image_Label.apply(lambda o: o.split('.')[0])
    df['Label'] = df.Image_Label.apply(lambda o: o.split('_')[1].lower())
    df.drop('Image_Label', axis=1, inplace=True)
    df = df[['Image', 'Label', 'EncodedPixels']]
    return df

# %%
ANNOTS = load_train_annotation(SOURCE/'train.csv')

# %%
ANNOTS.head()
# Out:
#      Image   Label  \
# 0  0011165    fish
# 1  0011165  flower
# 2  0011165  gravel
# 3  0011165   sugar
# 4  002be4f    fish
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              EncodedPixels
# 0  264918 937 266318 937 267718 937 269118 937 270518 937 271918 937 273318 937 274718 937 276118 937 277518 937 278918 937 280318 937 281718 937 283118 937 284518 937 285918 937 287318 937 288718 937 290118 937 291518 937 292918 937 294318 937 295718 937 297118 937 298518 937 299918 937 301318 937 302718 937 304118 937 305518 937 306918 937 308318 937 309718 937 311118 937 312518 937 313918 937 315318 937 316718 937 318118 937 319518 937 320918 937 322318 937 323718 937 325118 937 326518 937 327918 937 329318 937 330718 937 332118 937 333518 937 334918 937 336318 937 337718 937 339118 937 34...
# 1  1355565 1002 1356965 1002 1358365 1002 1359765 1002 1361165 1002 1362565 1002 1363965 1002 1365365 1002 1366765 1002 1368165 1002 1369565 1002 1370965 1002 1372365 1002 1373765 1002 1375165 1002 1376565 1002 1377965 1002 1379365 1002 1380765 1002 1382165 1002 1383565 1002 1384965 1002 1386365 1002 1387765 1002 1389165 1002 1390565 1002 1391965 1002 1393365 1002 1394765 1002 1396165 1002 1397565 1002 1398965 1002 1400365 1002 1401765 1002 1403165 1002 1404565 1002 1405965 1002 1407365 1002 1408765 1002 1410165 1002 1411565 1002 1412965 1002 1414365 1002 1415765 1002 1417165 1002 1418565 100...
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      NaN
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      NaN
# 4  233813 878 235213 878 236613 878 238010 881 239410 881 240810 881 242210 881 243610 881 245010 881 246410 881 247810 881 249210 881 250610 881 252010 881 253410 881 254810 881 256210 881 257610 881 259010 881 260410 881 261810 881 263210 881 264610 881 266010 881 267410 881 268810 881 270210 881 271610 881 273010 881 274410 881 275810 881 277210 881 278610 881 280010 881 281410 881 282810 881 284210 881 285610 881 287010 881 288410 881 289810 881 291210 881 292610 881 294010 881 295410 881 296810 881 298210 881 299610 881 301010 881 302410 881 303810 881 305210 881 306610 881 308010 881 30...

# %% [markdown]
# ### Rescaling the images
# The original size of the images is 2100 px in width and 1400 px in height.  To start off with something smaller, a `Transform` is created for rescaling the images.  Here, the aspect ratio is kept the same, so no cropping or squishing.

# %%
class RescaleTfm(TupleTransform):
    def __init__(self, max_w=210, resample=Image.BILINEAR): 
        self.max_w, self.resample = max_w, resample
        
    def encodes(self, o:PILImage): return o.resize_max(max_w=self.max_w, resample=self.resample)
    def encodes(self, o:PILMask): return o.resize_max(max_w=self.max_w, resample=Image.NEAREST)

# %%
SZ = 525

# %% [markdown]
# ### Decode Run-length Encoding

# %%
def rle_decode(mask_rle: str = '', shape: tuple = (1400, 2100)):
    '''
    Decode rle encoded mask.
    
    :param mask_rle: run-length as string formatted (start length)
    :param shape: (height, width) of array to return 
    Returns numpy array, 1 - mask, 0 - background
    
    Copied from https://www.kaggle.com/artgor/segmentation-in-pytorch-using-convenient-tools
    '''
    s = mask_rle.split()
    starts, lengths = [np.asarray(x, dtype=int) for x in (s[0:][::2], s[1:][::2])]
    starts -= 1
    ends = starts + lengths
    img = np.zeros(shape[0] * shape[1], dtype=np.uint8)
    for lo, hi in zip(starts, ends):
        img[lo:hi] = 1
    return img.reshape(shape, order='F')

# %%
class RLE_Decode(Transform):
    def __init__(self, cat, annots, img_shape): 
        self.cat, self.annots, self.img_shape = cat,  annots, img_shape
        
    def encodes(self, o):
        df = self.annots[self.annots.Image == o.stem].fillna('')
        px_rle = df[df.Label == self.cat].EncodedPixels.values[0]
        return rle_decode(px_rle, IMG_SHAPE)

# %%
ANNOTS[ANNOTS.Image == items[16].stem]
# Out:
#          Image   Label  \
# 10464  76ee28f    fish
# 10465  76ee28f  flower
# 10466  76ee28f  gravel
# 10467  76ee28f   sugar
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  EncodedPixels
# 10464  659 452 2059 452 3459 452 4859 452 6259 452 7659 452 9059 452 10459 452 11859 452 13259 452 14659 452 16059 452 17459 452 18859 452 20259 452 21659 452 23059 452 24459 452 25859 452 27259 452 28659 452 30059 452 31459 452 32859 452 34259 452 35659 452 37059 452 38459 452 39859 452 41259 452 42659 452 44059 452 45459 452 46859 452 48259 452 49659 452 51059 452 52459 452 53859 452 55259 452 56659 452 58059 452 59459 452 60859 452 62259 452 63659 452 65059 452 66459 452 67859 452 69259 452 70659 452 72059 452 73459 452 74859 452 76259 452 77659 452 79059 452 80459 452 81859 452 83259 452 8465...
# 10465                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      NaN
# 10466                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      NaN
# 10467                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      NaN

# %%
for cat in CATS: print(cat, RLE_Decode(cat, ANNOTS, IMG_SHAPE)(items[16]).sum())
# Out:
# fish 836662
# flower 0
# gravel 0
# sugar 0

# %% [markdown]
# ### DataSource

# %%
class Tensor2MaskTfm(TupleTransform):
    def encodes(self, o): return PILMask.create(o)

# %%
split_idx = RandomSplitter()(items)
tensor2mask = Tensor2MaskTfm()

tfms = [[PILImage.create], 
        [RLE_Decode('fish', ANNOTS, IMG_SHAPE), tensor2mask],
        [RLE_Decode('flower', ANNOTS, IMG_SHAPE), tensor2mask],
        [RLE_Decode('gravel', ANNOTS, IMG_SHAPE), tensor2mask],
        [RLE_Decode('sugar', ANNOTS, IMG_SHAPE), tensor2mask]]

dsrc = DataSource(items, tfms=tfms, splits=split_idx, n_inp=1)

# %%
dsrc.show(dsrc[18]);

# %%
dsrc[18]
# Out:
# (<local.vision.core.PILImage image mode=RGB size=2100x1400 at 0x7F9BE6A63F50>,
#  <local.vision.core.PILMask image mode=L size=2100x1400 at 0x7F9BE617B0D0>,
#  <local.vision.core.PILMask image mode=L size=2100x1400 at 0x7F9BE617B790>,
#  <local.vision.core.PILMask image mode=L size=2100x1400 at 0x7F9BE617B590>,
#  <local.vision.core.PILMask image mode=L size=2100x1400 at 0x7F9BE616E350>)

# %%
tensor(dsrc[18][1]).shape
# Out:
# torch.Size([1400, 2100])

# %% [markdown]
# ### DataBunch

# %%
rescale = RescaleTfm(max_w=SZ, resample=0)

# %%
rescale(dsrc[3])
# Out:
# (<local.vision.core.PILImage image mode=RGB size=525x350 at 0x7F9BE61896D0>,
#  <local.vision.core.PILMask image mode=L size=525x350 at 0x7F9BE6189BD0>,
#  <local.vision.core.PILMask image mode=L size=525x350 at 0x7F9BE61A8D10>,
#  <local.vision.core.PILMask image mode=L size=525x350 at 0x7F9BE61A8710>,
#  <local.vision.core.PILMask image mode=L size=525x350 at 0x7F9BE61A8750>)

# %%
after_item_tfms = [rescale, ToTensor]

# %%
after_batch_tfms = [Cuda(), IntToFloatTensor()]

# %%
dbch = dsrc.databunch(after_item=after_item_tfms, after_batch=after_batch_tfms, bs=2)

# %%
xb, *yb = dbch.one_batch()

# %%
len(yb)
# Out:
# 4

# %%
dbch.show_batch()

# %% [markdown]
# ### Normalize

# %%
imagenet_stats
# Out:
# ([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])

# %%
normalize = Normalize(*imagenet_stats)

# %% [markdown]
# Re-create `DataBunch`, adding `Normalize` transform:

# %%
after_item_tfms = [rescale, ToTensor]
after_batch_tfms = [Cuda(), IntToFloatTensor(), normalize]

# %%
dbch = dsrc.databunch(after_item=after_item_tfms, bs=2, after_batch=after_batch_tfms)

# %%
xb, *yb = dbch.one_batch()

# %%
xb.shape
# Out:
# torch.Size([8, 3, 350, 525])

# %%
for yb_ in yb: print(yb_.shape)
# Out:
# torch.Size([8, 350, 525])
# torch.Size([8, 350, 525])
# torch.Size([8, 350, 525])
# torch.Size([8, 350, 525])

# %% [markdown]
# ## Model

# %%
xb.shape, yb[0].shape, yb[1].shape, yb[2].shape, yb[3].shape
# Out:
# (torch.Size([8, 3, 140, 210]),
#  torch.Size([8, 140, 210]),
#  torch.Size([8, 140, 210]),
#  torch.Size([8, 140, 210]),
#  torch.Size([8, 140, 210]))

# %%
encoder = models.resnet34(pretrained=True)
encoder = nn.Sequential(*list(encoder.children())[:-2])

# %%
model = models.unet.DynamicUnet(encoder=encoder, n_classes=2, img_size=xb.shape[-2:], norm_type=None)

# %%
model.cuda();

# %%
pred = model(xb)

# %%
pred.shape
# Out:
# torch.Size([8, 2, 140, 210])

# %%
model[-1][0].in_channels, model[-1][0].out_channels, model[-1][0].kernel_size
# Out:
# (99, 2, (1, 1))

# %%
model[-1]
# Out:
# ConvLayer(
#   (0): Conv2d(99, 2, kernel_size=(1, 1), stride=(1, 1))
# )

# %%
ConvLayer(99, 2, ks=1, act_cls=None, norm_type=None)
# Out:
# ConvLayer(
#   (0): Conv2d(99, 2, kernel_size=(1, 1), stride=(1, 1))
# )

# %%
CATS
# Out:
# ['fish', 'flower', 'gravel', 'sugar']

# %%
class CloudsCustomHead(nn.Module):
    def __init__(self):
        super().__init__()
        #self.conv_clouds = [ConvLayer(99, 2, ks=1, act_cls=None, norm_type=None) for _ in CATS]
        self.conv_fish = ConvLayer(99, 2, ks=1, act_cls=None, norm_type=None)
        self.conv_flower = ConvLayer(99, 2, ks=1, act_cls=None, norm_type=None)
        self.conv_gravel = ConvLayer(99, 2, ks=1, act_cls=None, norm_type=None)
        self.conv_sugar = ConvLayer(99, 2, ks=1, act_cls=None, norm_type=None)
                
    def forward(self, o):
        #return tuple(m(o) for m in self.conv_clouds)
        return self.conv_fish(o)#, self.conv_flower(o), self.conv_gravel(o), self.conv_sugar(o)

# %%
custom_head = CloudsCustomHead()
custom_head
# Out:
# CloudsCustomHead(
#   (conv_fish): ConvLayer(
#     (0): Conv2d(99, 2, kernel_size=(1, 1), stride=(1, 1))
#   )
#   (conv_flower): ConvLayer(
#     (0): Conv2d(99, 2, kernel_size=(1, 1), stride=(1, 1))
#   )
#   (conv_gravel): ConvLayer(
#     (0): Conv2d(99, 2, kernel_size=(1, 1), stride=(1, 1))
#   )
#   (conv_sugar): ConvLayer(
#     (0): Conv2d(99, 2, kernel_size=(1, 1), stride=(1, 1))
#   )
# )

# %%
layers = list(model[:-1]) + [custom_head]

# %%
cloud_model = SequentialEx(*layers)

# %%
cloud_model.cuda()
# Out:
# SequentialEx(
#   (layers): ModuleList(
#     (0): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (4): Sequential(
#         (0): BasicBlock(
#           (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): BasicBlock(
#           (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (2): BasicBlock(
#           (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (5): Sequential(
#         (0): BasicBlock(
#           (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (downsample): Sequential(
#             (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): BasicBlock(
#           (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (2): BasicBlock(
#           (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (3): BasicBlock(
#           (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (6): Sequential(
#         (0): BasicBlock(
#           (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (downsample): Sequential(
#             (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): BasicBlock(
#           (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (2): BasicBlock(
#           (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (3): BasicBlock(
#           (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (4): BasicBlock(
#           (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (5): BasicBlock(
#           (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (7): Sequential(
#         (0): BasicBlock(
#           (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (downsample): Sequential(
#             (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): BasicBlock(
#           (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (2): BasicBlock(
#           (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Sequential(
#       (0): ConvLayer(
#         (0): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU()
#       )
#       (1): ConvLayer(
#         (0): Conv2d(1024, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU()
#       )
#     )
#     (4): UnetBlock(
#       (shuf): PixelShuffle_ICNR(
#         (0): ConvLayer(
#           (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1))
#           (1): ReLU()
#         )
#         (1): PixelShuffle(upscale_factor=2)
#       )
#       (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): ConvLayer(
#         (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU()
#       )
#       (conv2): ConvLayer(
#         (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU()
#       )
#       (relu): ReLU()
#     )
#     (5): UnetBlock(
#       (shuf): PixelShuffle_ICNR(
#         (0): ConvLayer(
#           (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1))
#           (1): ReLU()
#         )
#         (1): PixelShuffle(upscale_factor=2)
#       )
#       (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): ConvLayer(
#         (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU()
#       )
#       (conv2): ConvLayer(
#         (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU()
#       )
#       (relu): ReLU()
#     )
#     (6): UnetBlock(
#       (shuf): PixelShuffle_ICNR(
#         (0): ConvLayer(
#           (0): Conv2d(384, 768, kernel_size=(1, 1), stride=(1, 1))
#           (1): ReLU()
#         )
#         (1): PixelShuffle(upscale_factor=2)
#       )
#       (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): ConvLayer(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU()
#       )
#       (conv2): ConvLayer(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU()
#       )
#       (relu): ReLU()
#     )
#     (7): UnetBlock(
#       (shuf): PixelShuffle_ICNR(
#         (0): ConvLayer(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1))
#           (1): ReLU()
#         )
#         (1): PixelShuffle(upscale_factor=2)
#       )
#       (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): ConvLayer(
#         (0): Conv2d(192, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU()
#       )
#       (conv2): ConvLayer(
#         (0): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU()
#       )
#       (relu): ReLU()
#     )
#     (8): PixelShuffle_ICNR(
#       (0): ConvLayer(
#         (0): Conv2d(96, 384, kernel_size=(1, 1), stride=(1, 1))
#         (1): ReLU()
#       )
#       (1): PixelShuffle(upscale_factor=2)
#     )
#     (9): MergeLayer()
#     (10): ResBlock(
#       (convs): Sequential(
#         (0): ConvLayer(
#           (0): Conv2d(99, 99, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU()
#         )
#         (1): ConvLayer(
#           (0): Conv2d(99, 99, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (act): ReLU(inplace=True)
#     )
#     (11): CloudsCustomHead(
#       (conv_fish): ConvLayer(
#         (0): Conv2d(99, 2, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_flower): ConvLayer(
#         (0): Conv2d(99, 2, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_gravel): ConvLayer(
#         (0): Conv2d(99, 2, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_sugar): ConvLayer(
#         (0): Conv2d(99, 2, kernel_size=(1, 1), stride=(1, 1))
#       )
#     )
#   )
# )

# %%
y_test = cloud_model(xb)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-171-10d292e13cfc> in <module>
# ----> 1 y_test = cloud_model(xb)
#
# /opt/anaconda3/envs/fastai_dev/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     545             result = self._slow_forward(*input, **kwargs)
#     546         else:
# --> 547             result = self.forward(*input, **kwargs)
#     548         for hook in self._forward_hooks.values():
#     549             hook_result = hook(self, input, result)
#
# ~/fastai_dev/dev/local/layers.py in forward(self, x)
#     355         for l in self.layers:
#     356             res.orig = x
# --> 357             nres = l(res)
#     358             # We have to remove res.orig to avoid hanging refs and therefore memory leaks
#     359             res.orig = None
#
# /opt/anaconda3/envs/fastai_dev/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     545             result = self._slow_forward(*input, **kwargs)
#     546         else:
# --> 547             result = self.forward(*input, **kwargs)
#     548         for hook in self._forward_hooks.values():
#     549             hook_result = hook(self, input, result)
#
# /opt/anaconda3/envs/fastai_dev/lib/python3.7/site-packages/torch/nn/modules/container.py in forward(self, input)
#      90     def forward(self, input):
#      91         for module in self._modules.values():
# ---> 92             input = module(input)
#      93         return input
#      94
#
# /opt/anaconda3/envs/fastai_dev/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     545             result = self._slow_forward(*input, **kwargs)
#     546         else:
# --> 547             result = self.forward(*input, **kwargs)
#     548         for hook in self._forward_hooks.values():
#     549             hook_result = hook(self, input, result)
#
# /opt/anaconda3/envs/fastai_dev/lib/python3.7/site-packages/torch/nn/modules/pixelshuffle.py in forward(self, input)
#      41
#      42     def forward(self, input):
# ---> 43         return F.pixel_shuffle(input, self.upscale_factor)
#      44
#      45     def extra_repr(self):
#
# RuntimeError: CUDA out of memory. Tried to allocate 88.00 MiB (GPU 0; 7.43 GiB total capacity; 6.75 GiB already allocated; 56.94 MiB free; 139.81 MiB cached)

# %%
y_test.shape #y_test[0].shape, y_test[1].shape, y_test[2].shape, y_test[3].shape
# Out:
# torch.Size([8, 2, 140, 210])

# %%
yb[0].shape, yb[1].shape, yb[2].shape, yb[3].shape
# Out:
# (torch.Size([8, 140, 210]),
#  torch.Size([8, 140, 210]),
#  torch.Size([8, 140, 210]),
#  torch.Size([8, 140, 210]))

# %% [markdown]
# ## Model (customize inside `models.unet.DynamicUnet`)

# %%
del model

# %%
xb.shape, yb[0].shape, yb[1].shape, yb[2].shape, yb[3].shape
# Out:
# (torch.Size([8, 3, 350, 525]),
#  torch.Size([8, 350, 525]),
#  torch.Size([8, 350, 525]),
#  torch.Size([8, 350, 525]),
#  torch.Size([8, 350, 525]))

# %%
class CloudsCustomHead(nn.Module):
    def __init__(self, ni, n_classes, ks=1, act_cls=None, norm_type=None, **kwargs):
        super().__init__()
        self.conv_fish = ConvLayer(ni, n_classes, ks=ks, act_cls=act_cls, norm_type=norm_type, **kwargs)
        self.conv_flower = ConvLayer(ni, n_classes, ks=ks, act_cls=act_cls, norm_type=norm_type, **kwargs)
        self.conv_gravel = ConvLayer(ni, n_classes, ks=ks, act_cls=act_cls, norm_type=norm_type, **kwargs)
        self.conv_sugar = ConvLayer(ni, n_classes, ks=ks, act_cls=act_cls, norm_type=norm_type, **kwargs)
                
    def forward(self, o):
        return self.conv_fish(o), self.conv_flower(o), self.conv_gravel(o), self.conv_sugar(o)

# %%
class CustomizedDynamicUnet(SequentialEx):
    "Create a U-Net from a given architecture."
    def __init__(self, encoder, n_classes, img_size, blur=False, blur_final=True, self_attention=False,
                 y_range=None, last_cross=True, bottle=False, act_cls=defaults.activation,
                 init=nn.init.kaiming_normal_, norm_type=NormType.Batch, **kwargs):
        imsize = img_size
        sizes = model_sizes(encoder, size=imsize)
        sz_chg_idxs = list(reversed(models.unet._get_sz_change_idxs(sizes)))
        self.sfs = hook_outputs([encoder[i] for i in sz_chg_idxs], detach=False)
        x = dummy_eval(encoder, imsize).detach()

        ni = sizes[-1][1]
        middle_conv = nn.Sequential(ConvLayer(ni, ni*2, act_cls=act_cls, norm_type=norm_type, **kwargs),
                                    ConvLayer(ni*2, ni, act_cls=act_cls, norm_type=norm_type, **kwargs)).eval()
        x = middle_conv(x)
        layers = [encoder, BatchNorm(ni), nn.ReLU(), middle_conv]

        for i,idx in enumerate(sz_chg_idxs):
            not_final = i!=len(sz_chg_idxs)-1
            up_in_c, x_in_c = int(x.shape[1]), int(sizes[idx][1])
            do_blur = blur and (not_final or blur_final)
            sa = self_attention and (i==len(sz_chg_idxs)-3)
            unet_block = UnetBlock(up_in_c, x_in_c, self.sfs[i], final_div=not_final, blur=do_blur, self_attention=sa,
                                   act_cls=act_cls, init=init, norm_type=norm_type, **kwargs).eval()
            layers.append(unet_block)
            x = unet_block(x)

        ni = x.shape[1]
        if imsize != sizes[0][-2:]: layers.append(PixelShuffle_ICNR(ni, act_cls=act_cls, norm_type=norm_type))
        x = PixelShuffle_ICNR(ni)(x)
        if imsize != x.shape[-2:]: layers.append(Lambda(lambda x: F.interpolate(x, imsize, mode='nearest')))
        if last_cross:
            layers.append(MergeLayer(dense=True))
            ni += in_channels(encoder)
            layers.append(ResBlock(1, ni, ni//2 if bottle else ni, act_cls=act_cls, norm_type=norm_type, **kwargs))
            
        layers += [CloudsCustomHead(ni, n_classes, ks=1, act_cls=None, norm_type=norm_type, **kwargs)]
        
        apply_init(nn.Sequential(layers[3], layers[-2]), init)
        #apply_init(nn.Sequential(layers[2]), init)
        if y_range is not None: layers.append(SigmoidRange(*y_range))
        super().__init__(*layers)

    def __del__(self):
        if hasattr(self, "sfs"): self.sfs.remove()

# %%
encoder = models.resnet34(pretrained=True)
encoder = nn.Sequential(*list(encoder.children())[:-2])

# %%
rescale(dsrc[0][0]).shape
# Out:
# (350, 525)

# %%
model = CustomizedDynamicUnet(encoder=encoder, n_classes=2, img_size=rescale(dsrc[0][0]).shape, norm_type=None)

# %%
model
# Out:
# CustomizedDynamicUnet(
#   (layers): ModuleList(
#     (0): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (4): Sequential(
#         (0): BasicBlock(
#           (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): BasicBlock(
#           (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (2): BasicBlock(
#           (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (5): Sequential(
#         (0): BasicBlock(
#           (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (downsample): Sequential(
#             (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): BasicBlock(
#           (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (2): BasicBlock(
#           (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (3): BasicBlock(
#           (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (6): Sequential(
#         (0): BasicBlock(
#           (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (downsample): Sequential(
#             (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): BasicBlock(
#           (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (2): BasicBlock(
#           (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (3): BasicBlock(
#           (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (4): BasicBlock(
#           (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (5): BasicBlock(
#           (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (7): Sequential(
#         (0): BasicBlock(
#           (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (downsample): Sequential(
#             (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): BasicBlock(
#           (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (2): BasicBlock(
#           (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Sequential(
#       (0): ConvLayer(
#         (0): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU()
#       )
#       (1): ConvLayer(
#         (0): Conv2d(1024, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU()
#       )
#     )
#     (4): UnetBlock(
#       (shuf): PixelShuffle_ICNR(
#         (0): ConvLayer(
#           (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1))
#           (1): ReLU()
#         )
#         (1): PixelShuffle(upscale_factor=2)
#       )
#       (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): ConvLayer(
#         (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU()
#       )
#       (conv2): ConvLayer(
#         (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU()
#       )
#       (relu): ReLU()
#     )
#     (5): UnetBlock(
#       (shuf): PixelShuffle_ICNR(
#         (0): ConvLayer(
#           (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1))
#           (1): ReLU()
#         )
#         (1): PixelShuffle(upscale_factor=2)
#       )
#       (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): ConvLayer(
#         (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU()
#       )
#       (conv2): ConvLayer(
#         (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU()
#       )
#       (relu): ReLU()
#     )
#     (6): UnetBlock(
#       (shuf): PixelShuffle_ICNR(
#         (0): ConvLayer(
#           (0): Conv2d(384, 768, kernel_size=(1, 1), stride=(1, 1))
#           (1): ReLU()
#         )
#         (1): PixelShuffle(upscale_factor=2)
#       )
#       (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): ConvLayer(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU()
#       )
#       (conv2): ConvLayer(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU()
#       )
#       (relu): ReLU()
#     )
#     (7): UnetBlock(
#       (shuf): PixelShuffle_ICNR(
#         (0): ConvLayer(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1))
#           (1): ReLU()
#         )
#         (1): PixelShuffle(upscale_factor=2)
#       )
#       (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): ConvLayer(
#         (0): Conv2d(192, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU()
#       )
#       (conv2): ConvLayer(
#         (0): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU()
#       )
#       (relu): ReLU()
#     )
#     (8): PixelShuffle_ICNR(
#       (0): ConvLayer(
#         (0): Conv2d(96, 384, kernel_size=(1, 1), stride=(1, 1))
#         (1): ReLU()
#       )
#       (1): PixelShuffle(upscale_factor=2)
#     )
#     (9): Lambda(<function CustomizedDynamicUnet.__init__.<locals>.<lambda> at 0x7f9be62669e0>)
#     (10): MergeLayer()
#     (11): ResBlock(
#       (convs): Sequential(
#         (0): ConvLayer(
#           (0): Conv2d(99, 99, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU()
#         )
#         (1): ConvLayer(
#           (0): Conv2d(99, 99, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (act): ReLU(inplace=True)
#     )
#     (12): CloudsCustomHead(
#       (conv_fish): ConvLayer(
#         (0): Conv2d(99, 2, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_flower): ConvLayer(
#         (0): Conv2d(99, 2, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_gravel): ConvLayer(
#         (0): Conv2d(99, 2, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_sugar): ConvLayer(
#         (0): Conv2d(99, 2, kernel_size=(1, 1), stride=(1, 1))
#       )
#     )
#   )
# )

# %%
model.cuda();

# %%
y_test = model(xb)

# %%
len(y_test), y_test[0].shape, y_test[1].shape, y_test[2].shape, y_test[3].shape
# Out:
# (4,
#  torch.Size([8, 2, 350, 525]),
#  torch.Size([8, 2, 350, 525]),
#  torch.Size([8, 2, 350, 525]),
#  torch.Size([8, 2, 350, 525]))

# %%
del y_test
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-d693c470bb1d> in <module>
# ----> 1 del y_test
#
# NameError: name 'y_test' is not defined

# %% [markdown]
# ## Loss Function

# %% [markdown]
# For the loss function the *cross entropy loss* is calculated for each of the four clouds types, and then they are summed.

# %%
len(y_test), y_test[0].shape, len(yb), yb[0].shape
# Out:
# (4, torch.Size([8, 2, 140, 210]), 4, torch.Size([8, 140, 210]))

# %%
CrossEntropyLossFlat(axis=1)(y_test[0], yb[0])
# Out:
# tensor(0.6801, device='cuda:0', grad_fn=<NllLossBackward>)

# %%
class CloudsLoss(CrossEntropyLossFlat):
    def __init__(self, *args, axis=1, **kwargs): super().__init__(*args, axis=1, **kwargs)
    def __call__(self, inp, *targ, **kwargs):
        assert len(inp) == len(targ)
        f = super().__call__
        return sum([f(i, t, **kwargs) for i, t in zip(inp, targ)])

# %%
CloudsLoss()(y_test, *yb)
# Out:
# tensor(2.3216, device='cuda:0', grad_fn=<AddBackward0>)

# %% [markdown]
# ## Metrics

# %% [markdown]
# For the metric, the fraction of correctly classified pixels is shown for each cloud type.

# %%
def acc_seg(inp, *targ): 
    assert len(inp) == len(targ)
    return torch.stack([(i.argmax(dim=1) == t).float().mean() for i, t in zip(inp, targ)]).mean()

# %%
acc_seg(y_test, *yb)
# Out:
# tensor(0.6764, device='cuda:0')

# %% [markdown]
# ## Learner

# %%
ProgressCallback??

# %%
del learn

# %%
def get_param_grps(model):
    grps = [model[:3]], [model[4:-2]], [model[3], model[-2:]]
    return [trainable_params(nn.Sequential(*g)) for g in grps]

param_grps = get_param_grps(model)
len(param_grps), len(param_grps[0]), len(param_grps[1]), len(param_grps[2])
del param_grps

# %%
learn = Learner(dbch, model, loss_func=CloudsLoss(), metrics=acc_seg, splitter=get_param_grps)

# %%
learn.freeze_to(-1)

# %%
learn.lr_find(start_lr=1e-5, end_lr=1e2)

# %%
learn.fit(n_epoch=1, lr=1e-2)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>acc_seg</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.395552</td>
#       <td>1.368900</td>
#       <td>0.853617</td>
#       <td>17:13</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.opt.hypers
# Out:
# (#3) [{'sqr_mom': 0.99, 'wd': 0.01, 'lr': 0.01, 'mom': 0.9, 'eps': 1e-05},{'sqr_mom': 0.99, 'wd': 0.01, 'lr': 0.01, 'mom': 0.9, 'eps': 1e-05},{'sqr_mom': 0.99, 'wd': 0.01, 'lr': 0.01, 'mom': 0.9, 'eps': 1e-05}]

# %%
learn.save('maxw525_adam_grp2_2epch');

# %%
learn.load('maxw525_adam_grp2_2epch');

# %%
learn.freeze_to(-2)

# %%
learn.lr_find()

# %%
learn.fit(n_epoch=1, lr=[7e-6, 1e-5, 3e-5])
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>acc_seg</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.320010</td>
#       <td>1.226359</td>
#       <td>0.870807</td>
#       <td>18:44</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.recorder.plot_loss()

# %%
learn.save('maxw525_adam_grp_1_2_1epch');

# %%
learn.load('maxw525_adam_grp_1_2_1epch');

# %%
learn.unfreeze()

# %%
learn.lr_find()

# %%
learn.fit(n_epoch=1, lr=[1e-5, 2e-5, 3e-5])
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>acc_seg</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.206119</td>
#       <td>1.191298</td>
#       <td>0.876056</td>
#       <td>19:58</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('maxw525_adam_grp_0_1_2_1epch');

# %%
learn.load('maxw525_adam_grp_0_1_2_1epch');

# %%
learn.recorder.plot_loss()

# %%
learn.fit(n_epoch=10, lr=[3e-6, 1e-5, 6e-5])
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>acc_seg</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.152206</td>
#       <td>1.172208</td>
#       <td>0.878392</td>
#       <td>03:42</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.105476</td>
#       <td>1.146986</td>
#       <td>0.881735</td>
#       <td>03:44</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.093374</td>
#       <td>1.144949</td>
#       <td>0.880338</td>
#       <td>03:44</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.060273</td>
#       <td>1.164083</td>
#       <td>0.879070</td>
#       <td>03:45</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.027602</td>
#       <td>1.184621</td>
#       <td>0.878069</td>
#       <td>03:45</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.962088</td>
#       <td>1.231816</td>
#       <td>0.878962</td>
#       <td>03:45</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.955955</td>
#       <td>1.235984</td>
#       <td>0.875535</td>
#       <td>03:45</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.927839</td>
#       <td>1.262985</td>
#       <td>0.874050</td>
#       <td>03:45</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.873472</td>
#       <td>1.271438</td>
#       <td>0.873704</td>
#       <td>03:44</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.907881</td>
#       <td>1.319633</td>
#       <td>0.869889</td>
#       <td>03:46</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('adam_grp_0_1_2_10epch');

# %%
learn.load('adam_grp_0_1_2_10epch');

# %% [markdown]
# ## Look at results

# %%
from local.learner import _before_epoch, _after_epoch, _try_concat

# %%
@patch
def get_preds(self:Learner, ds_idx=1, dl=None, with_input=False, with_loss=False, with_decoded=False, act=None,
             save_preds=None, save_targs=None):
    print(':D')
    #self.epoch,self.n_epoch,self.loss = 0,1,tensor(0.)
    cb = GatherPredsCallback(with_input=with_input, with_loss=with_loss, save_preds=save_preds, save_targs=save_targs)
    with self.no_logging(), self.added_cbs(cb), self.loss_not_reduced(), self.no_mbar():
        self(_before_epoch)
        self._do_epoch_validate(ds_idx, dl)
        self(_after_epoch)
        if act is None: act = getattr(self.loss_func, 'activation', noop)
        res = []
        if len(cb.preds):
            #preds = act(torch.cat(cb.preds))
            preds = detuplify(tuple(act(torch.cat(o)) for o in zip(*cb.preds)))
            res.append(preds)
            if with_decoded: res.append(getattr(self.loss_func, 'decodes', noop)(preds))
        res.append(detuplify(tuple(torch.cat(o) for o in zip(*cb.targets))))
        if with_input: res = [tuple(_try_concat(o) for o in zip(*cb.inputs))] + res
        if with_loss:  res.append(torch.cat(cb.losses))
        return res

# %%
del learn
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-9814f7fc9f41> in <module>
# ----> 1 del learn
#
# NameError: name 'learn' is not defined

# %%
learn = Learner(dbch, model, loss_func=CloudsLoss(), metrics=acc_seg, splitter=get_param_grps)
learn.load('adam_grp_0_1_2_10epch');

# %%
preds, targs = learn.get_preds()

# %%
len(preds), len(targs)
# Out:
# (4, 4)

# %%
preds[0].shape, targs[0].shape, len(learn.dbunch.valid_ds)
# Out:
# (torch.Size([1109, 2, 140, 210]), torch.Size([1109, 140, 210]), 1109)

# %%
def preds2predmasks(preds): return tuple(o.argmax(dim=1) for o in preds)

# %%
def show_image_pred_targ(learn, predmasks, targs, idx=0):
    # Note: preds, targs = learn.get_preds()
    fig, axs = plt.subplots(nrows=5, ncols=2, figsize=(8, 15))
    for i, (cat, ax) in enumerate(zip(CATS, axs[1:])):
        PILMask.create(predmasks[i][idx] == 1).show(ctx=ax[0])
        PILMask.create(targs[i][idx] == 1).show(ctx=ax[1])
        ax[0].text(x=.5, y=.5, s=cat)
    learn.dbunch.valid_ds[idx][0].show(ctx=axs[0][0])
    learn.dbunch.show(learn.dbunch.valid_ds[idx], ctx=axs[0][1])
    plt.tight_layout()
    return fig, axs

# %%
predmasks = preds2predmasks(preds)

# %%
fig, axs = show_image_pred_targ(learn, predmasks, targs, idx=31)

# %% [markdown]
# ## Run-length encoding of masks

# %%
def mask2rle(img):
    '''
    Convert mask to rle.
    img: numpy array, 1 - mask, 0 - background
    Returns run length as string formated
    https://www.kaggle.com/artgor/segmentation-in-pytorch-using-convenient-tools
    '''
    pixels= img.T.flatten()
    pixels = np.concatenate([[0], pixels, [0]])
    runs = np.where(pixels[1:] != pixels[:-1])[0] + 1
    runs[1::2] -= runs[::2]
    return ' '.join(str(x) for x in runs)

# %%
tensormask = predmasks[1][23]
mask_rle = mask2rle(tensormask)

# %%
PILMask.create(rle_decode(mask_rle, shape=tensormask.shape)).show()

# %%
np.allclose(rle_decode(mask_rle, shape=tensormask.shape), tensormask)
# Out:
# True

# %% [markdown]
# ## Writing out for submission

# %% [markdown]
# Let's first try writing out for the validation set

# %%
learn.dbunch.valid_ds.items[:4]
# Out:
# [PosixPath('data/train_images/1dacc16.jpg'),
#  PosixPath('data/train_images/424f7a3.jpg'),
#  PosixPath('data/train_images/b6b6289.jpg'),
#  PosixPath('data/train_images/b570e82.jpg')]

# %%
df = pd.DataFrame(columns=['Image', 'Label', 'EncodedPixels'])
for ifpath, fpath in enumerate(learn.dbunch.valid_ds.items[:2]):
    for icat, cat in enumerate(CATS):
        row = dict(Image=fpath.stem, Label=cat, EncodedPixels=mask2rle(predmasks[icat][ifpath]))
        df = df.append(row, ignore_index=True)

df['Image_Label'] = df.apply(lambda o: o.Image + '.jpg_' + o.Label[0].upper() + o.Label[1:], axis=1)
# 5  291 13 308 1 311 2 430 14 445 1 448 1 451 2 457 1 569 2 572 15 588 2 591 4 706 2 709 28 846 3 851 14 868 1 870 3 985 5 992 13 1009 5 1125 34 1160 2 1266 35 1404 37 1544 37 1685 37 1824 37 1963 38 2104 30 2135 4 2245 30 2276 3 2385 35 2524 33 2664 31 2804 31 2943 32 3083 30 3115 1 3224 29 3366 25 3392 1 3505 28 3644 25 3671 1 3784 25 3924 25 4063 26 4204 21 4226 3 4344 25 4483 24 4508 3 4622 26 4650 1 4762 23 4787 2 4902 1 4904 22 4927 2 5042 1 5044 15 5060 7 5183 24 5324 17 5342 3 5347 1 5464 17 5482 2 5605 14 5621 2 5625 1 5744 15 5761 5 5885 1 5887 18 6025 1 6028 15 6045 1 6165 2 6169 2 ...
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      NaN
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      NaN

# %% [markdown]
# ## Test set

# %%
items_test = get_image_files(SOURCE/'test_images').sorted()

# %%
items_test = items_test[:10]

# %%
items_test
# Out:
# (#10) [data/test_images/002f507.jpg,data/test_images/0035ae9.jpg,data/test_images/0038327.jpg,data/test_images/004f759.jpg,data/test_images/005ba08.jpg,data/test_images/006440a.jpg,data/test_images/006f61b.jpg,data/test_images/0078e5a.jpg,data/test_images/008fc8a.jpg,data/test_images/0096937.jpg]

# %%
tfms_test = [[PILImage.create], 
             [lambda o: PILMask.create(torch.zeros(*IMG_SHAPE, dtype=torch.uint8))],
             [lambda o: PILMask.create(torch.zeros(*IMG_SHAPE, dtype=torch.uint8))],
             [lambda o: PILMask.create(torch.zeros(*IMG_SHAPE, dtype=torch.uint8))],
             [lambda o: PILMask.create(torch.zeros(*IMG_SHAPE, dtype=torch.uint8))]]

dsrc_test = DataSource(items_test, tfms=tfms_test, n_inp=1)

# %%
PILImage.create(items_test[6]).show()

# %%
dsrc.show(dsrc_test.train[6])

# %%
dbch_test = dsrc_test.databunch(after_item=after_item_tfms, bs=8, after_batch=after_batch_tfms, shuffle_train=False)

# %%
dbch_test.train_dl.show_batch()

# %%
dsrc_test.show(dbch_test.train_ds[6]);

# %%
PILImage.create(dbch_test.train_ds.items[6]).show()

# %%
xb, *yb = dbch_test.train_dl.one_batch()

# %%
xb.shape, yb[0].shape
# Out:
# (torch.Size([8, 3, 140, 210]), torch.Size([8, 140, 210]))

# %%
learn.dbunch = dbch_test

# %%
preds_test, targs_test = learn.get_preds(ds_idx=0)

# %%
len(preds_test), len(targs_test)
# Out:
# (4, 4)

# %%
predmasks_test = preds2predmasks(preds_test)

# %%
def show_image_pred_targ(learn, predmasks, targs, idx=0):
    # Have to redefine because now on `train_ds`
    # Note: preds, targs = learn.get_preds()
    fig, axs = plt.subplots(nrows=5, ncols=2, figsize=(8, 15))
    for i, (cat, ax) in enumerate(zip(CATS, axs[1:])):
        PILMask.create(predmasks[i][idx] == 1).show(ctx=ax[0])
        PILMask.create(targs[i][idx] == 1).show(ctx=ax[1])
        ax[0].text(x=.5, y=.5, s=cat)
    learn.dbunch.train_ds[idx][0].show(ctx=axs[0][0])
    learn.dbunch.show(learn.dbunch.train_ds[idx], ctx=axs[0][1])
    plt.tight_layout()
    return fig, axs

# %%
fig, axs = show_image_pred_targ(learn, predmasks_test, targs_test, idx=9)

# %%
df = pd.DataFrame(columns=['Image', 'Label', 'EncodedPixels'])
for ifpath, fpath in enumerate(learn.dbunch.train_ds.items):
    for icat, cat in enumerate(CATS):
        row = dict(Image=fpath.stem, Label=cat, EncodedPixels=mask2rle(predmasks_test[icat][ifpath]))
        df = df.append(row, ignore_index=True)

df['Image_Label'] = df.apply(lambda o: o.Image + '.jpg_' + o.Label[0].upper() + o.Label[1:], axis=1)
df.drop(['Image', 'Label'], inplace=True, axis=1)
df = df[['Image_Label', 'EncodedPixels']]

# %%
df
# Out:
#            Image_Label  \
# 0     002f507.jpg_Fish
# 1   002f507.jpg_Flower
# 2   002f507.jpg_Gravel
# 3    002f507.jpg_Sugar
# 4     0035ae9.jpg_Fish
# 5   0035ae9.jpg_Flower
# 6   0035ae9.jpg_Gravel
# 7    0035ae9.jpg_Sugar
# 8     0038327.jpg_Fish
# 9   0038327.jpg_Flower
# 10  0038327.jpg_Gravel
# 11   0038327.jpg_Sugar
# 12    004f759.jpg_Fish
# 13  004f759.jpg_Flower
# 14  004f759.jpg_Gravel
# 15   004f759.jpg_Sugar
# 16    005ba08.jpg_Fish
# 17  005ba08.jpg_Flower
# 18  005ba08.jpg_Gravel
# 19   005ba08.jpg_Sugar
# 20    006440a.jpg_Fish
# 21  006440a.jpg_Flower
# 22  006440a.jpg_Gravel
# 23   006440a.jpg_Sugar
# 24    006f61b.jpg_Fish
# 25  006f61b.jpg_Flower
# 26  006f61b.jpg_Gravel
# 27   006f61b.jpg_Sugar
# 28    0078e5a.jpg_Fish
# 29  0078e5a.jpg_Flower
# 30  0078e5a.jpg_Gravel
# 31   0078e5a.jpg_Sugar
# 32    008fc8a.jpg_Fish
# 33  008fc8a.jpg_Flower
# 34  008fc8a.jpg_Gravel
# 35   008fc8a.jpg_Sugar
# 36    0096937.jpg_Fish
# 37  0096937.jpg_Flower
# 38  0096937.jpg_Gravel
# 39   0096937.jpg_Sugar
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               EncodedPixels
# 0
# 1
# 2   9 2 12 3 19 5 25 1 27 96 125 5 147 124 273 2 283 134 419 2 423 132 556 1 560 1 562 137 702 135 842 137 982 137 1122 137 1262 137 1401 139 1541 419 1961 139 2101 2519 4621 139 4761 419 5181 139 5321 139 5461 139 5601 139 5741 139 5881 139 6021 139 6161 139 6301 139 6441 139 6581 139 6721 139 6861 139 7001 139 7141 139 7281 139 7421 139 7561 139 7701 139 7841 138 7981 139 8121 139 8261 139 8401 138 8541 138 8681 139 8821 139 8961 138 9101 138 9241 139 9381 137 9521 138 9661 138 9801 136 9938 2 9941 137 10081 138 10221 138 10361 136 10501 136 10641 138 10781 135 10917 2 10921 136 11061 136 11...
# 3
# 4   21351 2 21359 2 21363 3 21498 3 21504 4 21638 5 21645 2 21649 2 21778 5 21785 2 21789 2 21911 2 21915 1 21918 8 21927 1 21931 1 22052 1 22055 10 22066 3 22195 1 22197 7 22205 4 22335 9 22345 3 22471 14 22487 2 22611 2 22614 11 22627 1 22631 1 22754 2 22758 11 22771 1 22898 5 22907 2 23031 2 23034 3 23038 3 23043 3 23049 1 23171 2 23175 2 23178 3 23183 4 23314 1 23318 2 23323 1 23325 3 23591 6 23599 2 23603 1 23605 2 23731 6 23738 3 23745 2 23871 2 23874 1 23878 2 23886 2 24011 2 24014 1 24018 2 24150 6 24159 2 24164 4 24290 7 24298 3 24304 4 24431 1 24435 1 24438 3 24578 3 24713 2 24716 3 ...
